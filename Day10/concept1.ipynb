# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# 1. Generate random dataset
k = 5
dataset = make_blobs(n_samples=2500, centers = [[4,5], [0, -1], [2, -3], [1, 2], [5,2]], cluster_std = 0.8, random_state=42)
X, y = dataset
# 2. Apply K-Means
model = KMeans(n_clusters=k, random_state=42)
model.fit(X)

print("Dataset shape:", X.shape)

print("First 5 samples:")
print(X[:5])

print("Cluster Centroids:")
print(model.cluster_centers_)

print("First 10 labels:")
print(model.labels_[:10])
# Out:
# Dataset shape: (2500, 2)
# First 5 samples:
# [[ 1.81278411 -2.6269133 ]
#  [ 3.45888616  6.44075235]
#  [ 0.88566454 -1.09630493]
#  [ 4.90921548  2.17724678]
#  [ 1.64556478 -3.38359437]]
# Cluster Centroids:
# [[ 4.96417904  1.94117777]
#  [ 0.0442491  -0.95755139]
#  [ 4.00486106  5.03030007]
#  [ 0.98534099  1.99381367]
#  [ 2.01348547 -3.0160159 ]]
# First 10 labels:
# [4 2 1 0 4 2 4 3 0 4]
