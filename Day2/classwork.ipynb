# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
df = pd.DataFrame(arr, columns=['A', 'B', 'C'])
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
raw_url = r"https://drive.google.com/uc?export=download&id=1SaC087F3jrW5rPkcUOtVeQ2vraxR30NL"
df = pd.read_csv(raw_url)
df
# Out:
#      delivery_time
# 0        35.476999
# 1        31.032150
# 2        36.533820
# 3        42.661209
# 4        30.360926
# ..             ...
# 995      30.032298
# 996      44.583806
# 997      36.485900
# 998      28.001747
# 999      36.008079
#
# [1000 rows x 1 columns]
